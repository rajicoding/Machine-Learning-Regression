# %%
import pickle
from sklearn.preprocessing import StandardScaler

# %%
sc=pickle.load(open("Bodyfat_scalar.pkl",'rb'))

# %%
pre_input=sc.transform([[1.0853,25,173.55,72.35,38.5,93.6,87,99,56,36,21,31,29,19]])
# Out:
# C:\Users\Inst_\anaconda3\envs\aiml1\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
pre_input
# Out:
# array([[ 1.60090693, -1.57993206, -0.19033298,  0.77696066,  0.22548353,
#         -0.89801262, -0.54175557, -0.12463783, -0.68863413, -1.12316107,
#         -1.47225103, -0.43259163,  0.15836271,  0.85220942]])

# %%
data=pickle.load(open("Bodyfat_kbestfeatures.pkl",'rb'))

# %%
kbest=data["indices"]

# %%
preinput_kbest=pre_input[:,kbest]
preinput_kbest
# Out:
# array([[ 1.60090693, -0.89801262, -0.54175557]])

# %%
loaded_model=pickle.load(open("Bodyfat_model_svm.pkl",'rb'))
result=loaded_model.predict(preinput_kbest)

# %%
result
# Out:
# array([6.37780013])

# %%
pre_input1=sc.transform([[1.04,32,180.5,69.5,38.4,102,91.6,103.9,63.4,38.3,21.5,32.5,28.6,17.7]])
# Out:
# C:\Users\Inst_\anaconda3\envs\aiml1\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
preinput1_kbest=pre_input1[:,kbest]
preinput1_kbest
# Out:
# array([[-0.82235173,  0.14566949, -0.09033495]])

# %%
loaded_model=pickle.load(open("Bodyfat_model_svm.pkl",'rb'))
result1=loaded_model.predict(preinput1_kbest)

# %%
result1
# Out:
# array([26.0134122])
