# %%
import pickle
from sklearn.preprocessing import StandardScaler

# %%
sc=pickle.load(open("Bodyfat_scalar.pkl",'rb'))

# %%
pre_input=sc.transform([[1.0853,93.6,83]])
# Out:
# C:\Users\Inst_\anaconda3\envs\aiml1\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
pre_input
# Out:
# array([[ 1.60090693, -0.89801262, -0.93429524]])

# %%
loaded_model=pickle.load(open("Bodyfat_model_svm.pkl",'rb'))
result=loaded_model.predict(pre_input)

# %%
result
# Out:
# array([6.03611338])

# %%
pre_input1=sc.transform([[1.04,102,91.6]])
# Out:
# C:\Users\Inst_\anaconda3\envs\aiml1\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
loaded_model=pickle.load(open("Bodyfat_model_svm.pkl",'rb'))
result1=loaded_model.predict(pre_input1)

# %%
result1
# Out:
# array([26.0134122])
