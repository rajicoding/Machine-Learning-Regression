# %% [markdown]
# <style>
# div.jp-RenderedHTMLCommon {
#     background-color: #f0f0f0 !important;
#     border: 2px solid red !important;
# }
# </style>

# %% [markdown]
# <style>
# div.jp-RenderedHTMLCommon {
#     background-color: #f0f0f0 !important;
#     border: 2px solid red !important;
# }
# </style>

# %%
import pandas as pd

# %% [markdown]
# <h2 style="color: purple; font-family: Comic Sans MS;">Importing Dataset</h2>

# %%
dataset=pd.read_csv("bodyfat.csv")
dataset
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# ...

# %% [markdown]
# <h2 style="color: purple; font-family: Comic Sans MS;">Data Preprocesing</h2>

# %% [markdown]
# <h3 style="color: brown; font-family: Comic Sans MS;"> 1.Checking for Missing/null values</h3>

# %%
dataset.isna().sum()
# Out:
# Density    0
# BodyFat    0
# Age        0
# Weight     0
# Height     0
# Neck       0
# Chest      0
# Abdomen    0
# Hip        0
# Thigh      0
# Knee       0
# Ankle      0
# Biceps     0
# Forearm    0
# Wrist      0
# dtype: int64

# %% [markdown]
# <h3 style="color: brown; font-family: Comic Sans MS;">  2.Checking for Outliers</h3>

# %%
from Univariate import Univariate

# %%
# separating quan and qual columns from the dataset
quan,qual=Univariate.quanqual(dataset)
print(quan,"\n",qual)
# Out:
# ['Density', 'BodyFat', 'Age', 'Weight', 'Height', 'Neck', 'Chest', 'Abdomen', 'Hip', 'Thigh', 'Knee', 'Ankle', 'Biceps', 'Forearm', 'Wrist']
#  []

# %%
# performing descriptive analysis to find IQR, Lower and upper bound outlier range
descriptive=Univariate.univariate(dataset,quan)
descriptive
# Out:
#            Density    BodyFat         Age      Weight     Height       Neck  \
# Mean      1.055574  19.150794   44.884921  178.924405   70.14881  37.992063
# Median      1.0549       19.2        43.0       176.5       70.0       38.0
# Mode         1.061       20.4          40      152.25       71.5       38.5
# Q1:25%      1.0414     12.475       35.75       159.0      68.25       36.4
# Q2:50%      1.0549       19.2        43.0       176.5       70.0       38.0
# Q3:75%      1.0704       25.3        54.0       197.0      72.25     39.425
# 99%       1.095393     36.621        72.0      245.72       76.0     42.996
# Q4:100%     1.1089       47.5        81.0      363.15      77.75       51.2
# IQR          0.029     12.825       18.25        38.0        4.0      3.025
# 1.5rule     0.0435    19.2375      27.375        57.0        6.0     4.5375
# Lower       0.9979    -6.7625       8.375       102.0      62.25    31.8625
# ...

# %%
# Checking columns which have outliers based on upper and lower range value
lower,upper=Univariate.outliercolumns(quan,descriptive)
print(lower,"\n",upper)
# Out:
# ['Density', 'Height', 'Neck', 'Forearm', 'Wrist']
#  ['BodyFat', 'Weight', 'Neck', 'Chest', 'Abdomen', 'Hip', 'Thigh', 'Knee', 'Ankle', 'Biceps', 'Forearm', 'Wrist']

# %%
# replacing the outliers with appropriate lower or upper bound range
descriptive=Univariate.replaceoutliers(dataset,descriptive,lower,upper,quan)
descriptive
# Out:
#            Density    BodyFat         Age      Weight    Height       Neck  \
# Mean      1.055585  19.139038   44.884921  178.456548  70.27877  37.967808
# Median      1.0549       19.2        43.0       176.5      70.0       38.0
# Mode         1.061       20.4          40      152.25      71.5       38.5
# Q1:25%      1.0414     12.475       35.75       159.0     68.25       36.4
# Q2:50%      1.0549       19.2        43.0       176.5      70.0       38.0
# Q3:75%      1.0704       25.3        54.0       197.0     72.25     39.425
# 99%       1.095393     36.621        72.0      245.72      76.0     42.996
# Q4:100%     1.1089    44.5375        81.0       254.0     77.75    43.9625
# IQR          0.029     12.825       18.25        38.0       4.0      3.025
# 1.5rule     0.0435    19.2375      27.375        57.0       6.0     4.5375
# Lower       0.9979    -6.7625       8.375       102.0     62.25    31.8625
# ...

# %%
# checking for any outliers in any of the column
lower,upper=Univariate.outliercolumns(quan,descriptive)
print(lower,"\n",upper)
# Out:
# []
#  []

# %% [markdown]
# <h2 style="color: Purple; font-family: Comic Sans MS;"> Data Visualization</h2>

# %% [markdown]
# <h2 style="color: brown; font-family: Comic Sans MS;">  1.Univariate Analysis </h2>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.distplot(dataset["Weight"],hist=True,kde=True,kde_kws={'color':'red'})
plt.show()
# Out:
# C:\Users\Inst_\AppData\Local\Temp\ipykernel_404\2796951874.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["Weight"],hist=True,kde=True,kde_kws={'color':'red'})

# %%
sns.distplot(dataset["Height"],hist=True,kde=True,kde_kws={'color':'red'})
plt.show()
# Out:
# C:\Users\Inst_\AppData\Local\Temp\ipykernel_404\1226687409.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["Height"],hist=True,kde=True,kde_kws={'color':'red'})

# %%
sns.distplot(dataset["BodyFat"],hist=True,kde=True,kde_kws={'color':'red'})
plt.show()
# Out:
# C:\Users\Inst_\AppData\Local\Temp\ipykernel_404\1866903262.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["BodyFat"],hist=True,kde=True,kde_kws={'color':'red'})

# %%
sns.distplot(dataset["Age"],hist=True,kde=True,kde_kws={'color':'red'})
plt.show()
# Out:
# C:\Users\Inst_\AppData\Local\Temp\ipykernel_404\2942714366.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["Age"],hist=True,kde=True,kde_kws={'color':'red'})

# %%
sns.distplot(dataset["Density"],hist=True,kde=True,kde_kws={'color':'red'})
plt.show()
# Out:
# C:\Users\Inst_\AppData\Local\Temp\ipykernel_404\2626479226.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["Density"],hist=True,kde=True,kde_kws={'color':'red'})

# %%
sns.boxplot(y=dataset["Neck"])
plt.show()

# %%
sns.boxplot(y=dataset["Thigh"])
plt.show()

# %%
sns.boxplot(y=dataset["Chest"])
plt.show()

# %%
sns.boxplot(y=dataset["Hip"])
plt.show()

# %%
sns.boxplot(y=dataset["Biceps"])
plt.show()

# %%
sns.boxplot(y=dataset["Forearm"])
plt.show()

# %%
sns.boxplot(y=dataset["Wrist"])
plt.show()

# %%
sns.boxplot(y=dataset["Knee"])
plt.show()

# %%
sns.boxplot(y=dataset["Ankle"])
plt.show()

# %% [markdown]
# <h2 style="color: brown; font-family: Comic Sans MS;">  2.Bivariate Analysis </h2>

# %% [markdown]
# <h2 style= "color:darkblue; font-family: Comic Sans MS;">
#  1. Which of the parameters is highly related to body fat?
# </h2>

# %%
dataset.corr(numeric_only=True)
# Out:
#           Density   BodyFat       Age    Weight    Height      Neck     Chest  \
# Density  1.000000 -0.987791 -0.277867 -0.607924  0.054693 -0.475266 -0.686428
# BodyFat -0.987791  1.000000  0.292100  0.627178 -0.039527  0.493320  0.706564
# Age     -0.277867  0.292100  1.000000 -0.015143 -0.239979  0.118277  0.181611
# Weight  -0.607924  0.627178 -0.015143  1.000000  0.493163  0.813718  0.893084
# Height   0.054693 -0.039527 -0.239979  0.493163  1.000000  0.328843  0.219752
# Neck    -0.475266  0.493320  0.118277  0.813718  0.328843  1.000000  0.774155
# Chest   -0.686428  0.706564  0.181611  0.893084  0.219752  0.774155  1.000000
# Abdomen -0.813525  0.827888  0.240314  0.877327  0.176770  0.733592  0.911014
# Hip     -0.629468  0.645717 -0.057722  0.930751  0.368617  0.702405  0.820746
# Thigh   -0.557786  0.565269 -0.209950  0.855170  0.317499  0.667499  0.712372
# Knee    -0.493584  0.509030  0.012761  0.851154  0.481081  0.653008  0.710765
# ...

# %% [markdown]
# <p style= "color:darkblue; font-size: 18px; line-height: 1.6; font-family: Comic Sans MS;">
#  Plotting heat map to explain it
# </p>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
corr_matrix=dataset.corr(numeric_only=True)
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, cmap="YlGnBu", annot=True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2 style= "color:darkblue; line-height: 1.6; font-family: Comic Sans MS;">
# 2.Do taller people weigh more? What is the relationship between height and weight?
# </h2>

# %%
plt.figure(figsize=(8,5))
sns.lineplot(x='Height',y='Weight', data=dataset, marker='o',color='red')
plt.title("Height vs Weight", fontsize=16)
plt.xlabel("Height", fontsize=12)
plt.ylabel("Weight", fontsize=12)
plt.show()

# %% [markdown]
# <ul style="font-family: Comic Sans Ms; font-size: 18px; color:green;">
#     <li>As the height increases, weight increases and decreases for some data points, so we can say that height doesn't
#     determine the weight of a member</li>
#     <li>We didn't have a certain pattern, so height and weight are not related with each other </li>
# </ul>

# %% [markdown]
# <h2 style= "color:darkblue; line-height: 1.6;font-family: Comic Sans MS;">
# 3.How many members have a minimum and maximum body fat percentage in the dataset?
# <h2>

# %%
df=dataset[(dataset.BodyFat==0.0)]
df
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen   Hip  Thigh  \
# 181   1.1089      0.0   40   118.5    68.0  33.8   79.3     69.4  85.0   47.2
#
#      Knee  Ankle  Biceps  Forearm  Wrist
# 181  33.5   20.2    27.7     24.6   16.5

# %%
# dropping the row with body fat '0' from the dataset
pre_dataset=dataset.drop(dataset[dataset['BodyFat']==0.0].index)

# %%
pre_dataset
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# ...

# %%
pre_dataset.to_csv("Preprocessed_dataset.csv", index=False)

# %%
def min_max_bodyfat(dataset):
    min_Val_bf=dataset["BodyFat"].min()
    max_Val_bf=dataset["BodyFat"].max()
    min_rows = dataset[dataset["BodyFat"]==dataset["BodyFat"].min()]
    max_rows = dataset[dataset["BodyFat"]==dataset["BodyFat"].max()]
    return min_Val_bf,max_Val_bf,min_rows, max_rows

# %%
min_val,max_val,min_rows,max_rows= min_max_bodyfat(pre_dataset)
print("Minimum bodyfat percentage is:",min_val)
print("Members who has minimum bodyfat percentage:")
print(min_rows.to_string(index=False))
print("Maximum bodyfat percentage is:",max_val)
print("Members who has maximum bodyfat percentage:")
print(max_rows.to_string(index=False))
# Out:
# Minimum bodyfat percentage is: 0.7
# Members who has minimum bodyfat percentage:
#  Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen  Hip  Thigh  Knee  Ankle  Biceps  Forearm  Wrist
#   1.0983      0.7   35  125.75    65.5  34.0   90.8     75.0 89.2   50.0  34.8   22.0    24.8     25.9   16.9
# Maximum bodyfat percentage is: 44.5375
# Members who has maximum bodyfat percentage:
#  Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen   Hip  Thigh  Knee  Ankle  Biceps  Forearm  Wrist
#   0.9979  44.5375   51   219.0    64.0  41.2  119.8   121.45 112.8   62.5  36.9   23.6    34.7     29.1   18.4

# %% [markdown]
# <ul style="font-family: Comic Sans Ms; font-size: 20px; color:green;">
#     <li>One of the member has bodyfat as 0.7(minimumvalue) but this is not advisable for having such a value to maintain good health</li>
#     <li>One of the member has higher bodyfat(44.537) and falls under over fat category</li>
# </ul>

# %% [markdown]
# <h2 style= "color:darkblue; font-family: Comic Sans MS;">
# 4.Find out if people lose weight as they age. What is the relationship between age and weight<h2>

# %%
plt.figure(figsize=(8,5))
sns.lineplot(x='Age',y='Weight', data=pre_dataset, marker='o',color='green')
plt.title("Age vs Weight", fontsize=16)
plt.xlabel("Age", fontsize=12)
plt.ylabel("Weight", fontsize=12)
plt.show()

# %% [markdown]
# <ul style="font-family: Comic Sans Ms; font-size: 18px; color:green;">
#     <li>As age increase, weight is increased for some data points but got decreased for some data points</li>
#     <li>There is no particular pattern to determine that older people lose weight</li>
#     <li>Some of them lose weight while others gain weight as per the graph</li>
# </ul>

# %%
pre_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 251 entries, 0 to 251
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Density  251 non-null    float64
#  1   BodyFat  251 non-null    float64
#  2   Age      251 non-null    int64
#  3   Weight   251 non-null    float64
#  4   Height   251 non-null    float64
#  5   Neck     251 non-null    float64
#  6   Chest    251 non-null    float64
#  7   Abdomen  251 non-null    float64
#  8   Hip      251 non-null    float64
#  9   Thigh    251 non-null    float64
#  10  Knee     251 non-null    float64
#  11  Ankle    251 non-null    float64
#  12  Biceps   251 non-null    float64
#  13  Forearm  251 non-null    float64
#  14  Wrist    251 non-null    float64
# dtypes: float64(14), int64(1)
# memory usage: 31.4 KB

# %%
pre_dataset
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# ...

# %% [markdown]
# <h2 style= "color:darkblue; font-family: Comic Sans MS;">
# 5 Classify the members as small, medium and large frame.And determine how many of them fall under each category?
# <h2>

# %%
# adding bmi column to dataframe
df=pre_dataset.copy(deep=True)
df["BMI"] = (703 * df["Weight"]) / (df["Height"] ** 2)

# Classify frame size based on BMI
def classify_frame(bmi):
    if bmi < 18.5:
        return "Small"
    elif 18.5 <= bmi < 25:
        return "Medium"
    else:
        return "Large"

df["Frame"] = df["BMI"].apply(classify_frame)
df
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist        BMI   Frame
# ...

# %%
small_count=(df["Frame"]=="Small").sum()
print("Members falls under small frame:",  small_count)
med_count=(df["Frame"]=="Medium").sum()
print("Members falls under medium frame:", med_count)
Lar_count=(df["Frame"]=="Large").sum()
print("Members falls under large Frame:", Lar_count)
# Out:
# Members falls under small frame: 0
# Members falls under medium frame: 124
# Members falls under large Frame: 127

# %% [markdown]
# <ul style="font-family: Comic Sans Ms; font-size:20px; color:green;">
#     <li>124 members fall under medium frame, i.e 49.4 %</li>
#     <li>127 members fall under large frame, i.e 51%</li>
#     <li>None of them belonged to small frame</li>
#     <li>Members have BMI greater than or equal to 18.5</li>
# </ul>

# %% [markdown]
# <h2 style= "color:darkblue; font-family: Comic Sans MS;">
# 6.How many members are short, average and tall in the group
# <h2>

# %%
def apply_height_type(df1):
    Height_category = []
# If value is a tuple, take the first element
    for value in enumerate(df1["Height"]):
        if isinstance(value, tuple):
            value = value[0]
   
        if(value<66):
            Height_category.append("Short")
        elif(value>72):
            Height_category.append("Tall")
        else:
            Height_category.append("Average")
    return Height_category

# %%
df["Height_cat"]=apply_height_type(df)

# %%
df
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist        BMI   Frame Height_cat
# ...

# %%
short_count=(df["Height_cat"]=="Short").sum()
print("shorter members of the group are:",short_count)
avg_count = (df["Height_cat"]=="Average").sum()
print("Members with average height are:",avg_count)
tall_count=(df["Height_cat"]=="Tall").sum()
print("Taller members of the group are:",tall_count)
# Out:
# shorter members of the group are: 66
# Members with average height are: 7
# Taller members of the group are: 178

# %% [markdown]
# <ul style="font-family: Comic Sans Ms; font-size:20px; color:green;">
#     <li>Most of the members in the group are tall(i.e 71%)</li>
#     <li>Some of the members in the group are short(i.e 26%)</li>
#     <li>None of them belonged to small frame</li>
#     <li>Members have BMI greater than or equal to 18.5</li>
# </ul>

# %% [markdown]
# <h2 style= "color:darkblue; font-family: Comic Sans MS;">
# 7.How many of them fall under the overfat category with respect to body fat percentage
# <h2>

# %%
def bodyfat_check(df1):
    bodyfat_cat=[]
    for value in df["BodyFat"]:
        if(value>25):
            bodyfat_cat.append("Overfat")
        elif(value<5):
            bodyfat_cat.append("Lean")
        else:
            bodyfat_cat.append("healthy")
    return bodyfat_cat

# %%
df["bodyfat_cat"]=bodyfat_check(df)

# %%
df
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist        BMI   Frame Height_cat  \
# ...

# %%
over_count=(df["bodyfat_cat"]=="Overfat").sum()
print("Members fall under overfat category are:",over_count)
# Out:
# Members fall under overfat category are: 66

# %% [markdown]
# <p style= "color:green; font-size: 20px; line-height: 1.6; font-family: Comic Sans MS;">
# 26% of the members fall under overfat category
# </p>

# %% [markdown]
# <h2 style= "color:darkblue; font-family: Comic Sans MS;">
# 8. How many of them fall under the lean category with respect to body fat percentage
# <h2>

# %%
lean_count=(df["bodyfat_cat"]=="Lean").sum()
print("Members fall under lean category are:",lean_count)
# Out:
# Members fall under lean category are: 7

# %% [markdown]
# <ul style="font-family: Comic Sans Ms; font-size:20px; color:green;">
#     <li>Only few members are lean in the group(7,i.e.3%)</li>
#     <li>Most probably the members who are lean might have average height</li>
# </ul>

# %%
df.to_csv("pre_dataset_added_columns.csv",index=False)

# %% [markdown]
# <h2 style= "color:darkblue; font-family: Comic Sans MS;">
# 9.Test the Analysis of Variance between abdomen and weight at a significance level of 5% (Make a decision using Hypothesis testing)
# <h2>

# %%
import scipy.stats as stats
stats.f_oneway(pre_dataset["Abdomen"],pre_dataset['Weight'])
# Out:
# F_onewayResult(statistic=np.float64(2224.287717660033), pvalue=np.float64(3.3522210068684144e-186))

# %% [markdown]
# <ul style="font-family: Comic Sans Ms; font-size:20px; color:green;">
#     <li>H0: There is no significant difference between abdomen and weight of the students</li>
#     <li>H1: There is significant difference between abdomen and weight of the students</li>
#     <li>Reject null hypothesis: if p<0.05</li>
#     <li>Here p-value is (3.3522210068684144e-186)<0.05</li>
#     <li>Hence reject null hypothesis and accept alternate hypothesis</li>
# </ul>

# %% [markdown]
# <h2 style= "color:darkblue; font-family: Comic Sans MS;">
# 10.Convert the normal distribution to the standard normal distribution for the body fat percentage column
# <h2>

# %%
# Converting normal distribution to Standard normal distribution
# defining the function with function name stdNBgraph and pre_dataset to be passed as parameter
def stdNBgraph(dataset):
# import seaborn library for plotting the graph    
    import seaborn as sns
# calculating the mean for the given column in the dataset using mean() function and assign it to mean variable
    mean=dataset.mean()
# calculating the standard deviation for the given column in the dataset using std() function and assigne it to std variable
    std=dataset.std()
# each values of particular column in dataset is store in list i and assigned to  list values    
    values = [i for i in dataset]
# z_score is calculated for each values in dataset and stored to list z_score    
    z_score =[((j-mean)/std) for j in values]
# density plot with respect to the given column in the dataset is plotted using distplot method by passing z_score as parameters
# kde=True so the curve is drawn in the plot    
    sns.distplot(z_score,kde=True)
# summation of the z_score divided by number of z_score values is calculated    
    (sum(z_score)/len(z_score))

# %%
stdNBgraph(pre_dataset["BodyFat"])
# Out:
# C:\Users\Inst_\AppData\Local\Temp\ipykernel_404\220394938.py:16: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score,kde=True)

# %% [markdown]
# <h2 style= "color:darkblue; font-family: Comic Sans MS;">
# 14. What is the probability Density Function of the body fat percentage range from 20 to 35%
# <h2>

# %%
# function to display the probability density function for the given range
def get_pdf_probability(dataset,startrange,endrange):
#importing the required libraries for plotting the graph
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
# using seaborn plotting the graph with distplot method
# kde=True so the curve for probability density plot
# color for curve is given as red using kde _kws attribute
# color for the histogram plot is given as green using color attribute
    ax=sns.distplot(dataset,kde=True,kde_kws={'color':"red"},color='Green')  
# vertical lines for startrange and endrange is drawn using axvline method of pyplot and color of the line is given as blue 
    pyplot.axvline(startrange,color='blue')
    pyplot.axvline(endrange,color='blue')
# generate a sample
    sample=dataset
# calculate the mean and standard deviation using  mean() and std() and assign it to sample_mean and sample_std variable    
    sample_mean=sample.mean()
    sample_std=sample.std()
# Formatting the mean and standard deviation upto 3 decimal and printing the same
    print('Mean=%.3f,Standard deviation=%.3f'%(sample_mean,sample_std))
# define the distribution
    dist=norm(sample_mean,sample_std)
# sample probabilities for a range of outcomes
# list named value is created, values of the list is generated between the given range(start and endrange by the user)  stored in the list named value and assigned back to list values    
    values=[value for value in range(startrange,endrange)] 
# adding print statement to compare with usual method of using for loop with 3 lines
   
# pdf method from dist class is used to calculate the probability for each value available in values list 
# and all the probability values are stored in probabilities list   
    probabilities=[float(dist.pdf(value)) for value in values]
#adding all the probabiltiy value of the given range and stored in to the variable prob  
    prob=(sum(probabilities))
#Printing the overall probability value from startrange to endrange provided by the user
    print("the area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
pre_dataset=pd.read_csv("preprocessed_dataset.csv")

# %%
get_pdf_probability(pre_dataset["BodyFat"],20,35)
# Out:
# Mean=19.215,Standard deviation=8.259
# the area between range(20,35):0.45421741174181124
# C:\Users\Inst_\AppData\Local\Temp\ipykernel_404\1469728213.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(dataset,kde=True,kde_kws={'color':"red"},color='Green')
# 0.45421741174181124
