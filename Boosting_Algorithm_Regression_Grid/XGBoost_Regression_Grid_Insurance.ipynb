# %%
import pandas as pd
import xgboost as xgb

# %%
Dataset=pd.read_csv("insurance_pre.csv")
Dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
Dataset.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges'], dtype='object')

# %%
# Here categorical data(state) is available in the dataset which is converted to numerical data 
# As the categorical data available is nominal, one hot coding method is used to convert it into numerical data
Dataset=pd.get_dummies(Dataset,dtype=int,drop_first=True)
Dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
Dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
#Input and output split
independent=Dataset[['age', 'bmi', 'children','sex_male','smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
Dependent=Dataset[["charges"]]
Dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
# model creation using GridsearchCV
from sklearn.model_selection import GridSearchCV
param_grid={'eta':[0.05,0.07,0.1],
            'max_depth':[3],
             'subsample':[0.7,0.9],
             'colsample_bytree':[0.7,0.9],
             'tree_method':['exact','auto','hist','approx']}
grid=GridSearchCV(xgb.XGBRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,Dependent)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# GridSearchCV(estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, feature_weights=None,
#                                     gamma=None, grow_policy=None,
#                                     importance_type=None,
#                                     interaction_constraints=None,
#                                     lear...
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.7, 0.9],
#                          'eta': [0.05, 0.07, 0.1], 'max_depth': [3],
#                          'subsample': [0.7, 0.9],
#                          'tree_method': ['exact', 'auto', 'hist', 'approx']},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.493432      0.257637         0.006045        0.000422
# 1        0.287349      0.035589         0.006287        0.000677
# 2        0.201150      0.170657         0.007482        0.003640
# 3        0.130928      0.012070         0.016588        0.003796
# 4        0.170899      0.012840         0.013215        0.002468
# 5        0.169270      0.021219         0.024961        0.005824
# 6        0.228825      0.027071         0.022646        0.006073
# 7        0.178091      0.018525         0.018221        0.002553
# 8        0.216221      0.018027         0.031392        0.016953
# 9        0.291147      0.047034         0.036268        0.017508
# 10       0.273501      0.026213         0.028373        0.006672
# 11       0.246757      0.015915         0.023349        0.003113
# 12       0.274034      0.005395         0.026061        0.003364
# 13       0.225940      0.011151         0.022622        0.001904
# 14       0.189318      0.003912         0.020485        0.001379
# 15       0.203732      0.008007         0.026767        0.002822
# 16       0.257503      0.010297         0.019568        0.004158
# 17       0.190098      0.012092         0.016640        0.001641
# 18       0.161836      0.005102         0.023264        0.003829
# 19       0.195895      0.007960         0.019537        0.004114
# 20       0.215292      0.011943         0.019956        0.002307
# 21       0.170895      0.006418         0.020971        0.004319
# 22       0.217240      0.033908         0.034432        0.010814
# 23       0.272141      0.012949         0.025574        0.004207
# 24       0.344904      0.023825         0.019449        0.002166
# 25       0.217388      0.013241         0.017312        0.002869
# 26       0.180412      0.007196         0.022354        0.002121
# 27       0.200916      0.011146         0.022442        0.004771
# 28       0.261650      0.014648         0.021665        0.003949
# 29       0.194126      0.010708         0.017491        0.003255
# 30       0.179902      0.007433         0.018045        0.002971
# 31       0.175424      0.008864         0.019052        0.003008
# 32       0.235691      0.007950         0.016931        0.002121
# 33       0.169922      0.004287         0.020021        0.003093
# 34       0.200514      0.024496         0.027212        0.003703
# 35       0.226866      0.006610         0.023317        0.004920
# 36       0.259425      0.017687         0.020105        0.002289
# 37       0.182253      0.004387         0.019687        0.003074
# 38       0.173753      0.006498         0.019386        0.002760
# 39       0.177776      0.004804         0.020327        0.001136
# 40       0.220365      0.006922         0.017561        0.002278
# 41       0.167487      0.002857         0.014570        0.000794
# 42       0.168533      0.004183         0.019701        0.002688
# 43       0.191096      0.009030         0.018077        0.001123
# 44       0.282246      0.035172         0.032479        0.013599
# 45       0.266094      0.021843         0.041153        0.014619
# 46       0.308673      0.026993         0.025379        0.010744
# 47       0.207495      0.009265         0.008264        0.002468
#
#     param_colsample_bytree  param_eta  param_max_depth  param_subsample  \
# 0                      0.7       0.05                3              0.7
# 1                      0.7       0.05                3              0.7
# 2                      0.7       0.05                3              0.7
# 3                      0.7       0.05                3              0.7
# 4                      0.7       0.05                3              0.9
# 5                      0.7       0.05                3              0.9
# 6                      0.7       0.05                3              0.9
# 7                      0.7       0.05                3              0.9
# 8                      0.7       0.07                3              0.7
# 9                      0.7       0.07                3              0.7
# 10                     0.7       0.07                3              0.7
# 11                     0.7       0.07                3              0.7
# 12                     0.7       0.07                3              0.9
# 13                     0.7       0.07                3              0.9
# 14                     0.7       0.07                3              0.9
# 15                     0.7       0.07                3              0.9
# 16                     0.7       0.10                3              0.7
# 17                     0.7       0.10                3              0.7
# 18                     0.7       0.10                3              0.7
# 19                     0.7       0.10                3              0.7
# 20                     0.7       0.10                3              0.9
# 21                     0.7       0.10                3              0.9
# 22                     0.7       0.10                3              0.9
# 23                     0.7       0.10                3              0.9
# 24                     0.9       0.05                3              0.7
# 25                     0.9       0.05                3              0.7
# 26                     0.9       0.05                3              0.7
# 27                     0.9       0.05                3              0.7
# 28                     0.9       0.05                3              0.9
# 29                     0.9       0.05                3              0.9
# 30                     0.9       0.05                3              0.9
# 31                     0.9       0.05                3              0.9
# 32                     0.9       0.07                3              0.7
# 33                     0.9       0.07                3              0.7
# 34                     0.9       0.07                3              0.7
# 35                     0.9       0.07                3              0.7
# 36                     0.9       0.07                3              0.9
# 37                     0.9       0.07                3              0.9
# 38                     0.9       0.07                3              0.9
# 39                     0.9       0.07                3              0.9
# 40                     0.9       0.10                3              0.7
# 41                     0.9       0.10                3              0.7
# 42                     0.9       0.10                3              0.7
# 43                     0.9       0.10                3              0.7
# 44                     0.9       0.10                3              0.9
# 45                     0.9       0.10                3              0.9
# 46                     0.9       0.10                3              0.9
# 47                     0.9       0.10                3              0.9
#
#    param_tree_method                                             params  \
# 0              exact  {'colsample_bytree': 0.7, 'eta': 0.05, 'max_de...
# 1               auto  {'colsample_bytree': 0.7, 'eta': 0.05, 'max_de...
# 2               hist  {'colsample_bytree': 0.7, 'eta': 0.05, 'max_de...
# 3             approx  {'colsample_bytree': 0.7, 'eta': 0.05, 'max_de...
# 4              exact  {'colsample_bytree': 0.7, 'eta': 0.05, 'max_de...
# 5               auto  {'colsample_bytree': 0.7, 'eta': 0.05, 'max_de...
# 6               hist  {'colsample_bytree': 0.7, 'eta': 0.05, 'max_de...
# 7             approx  {'colsample_bytree': 0.7, 'eta': 0.05, 'max_de...
# 8              exact  {'colsample_bytree': 0.7, 'eta': 0.07, 'max_de...
# 9               auto  {'colsample_bytree': 0.7, 'eta': 0.07, 'max_de...
# 10              hist  {'colsample_bytree': 0.7, 'eta': 0.07, 'max_de...
# 11            approx  {'colsample_bytree': 0.7, 'eta': 0.07, 'max_de...
# 12             exact  {'colsample_bytree': 0.7, 'eta': 0.07, 'max_de...
# 13              auto  {'colsample_bytree': 0.7, 'eta': 0.07, 'max_de...
# 14              hist  {'colsample_bytree': 0.7, 'eta': 0.07, 'max_de...
# 15            approx  {'colsample_bytree': 0.7, 'eta': 0.07, 'max_de...
# 16             exact  {'colsample_bytree': 0.7, 'eta': 0.1, 'max_dep...
# 17              auto  {'colsample_bytree': 0.7, 'eta': 0.1, 'max_dep...
# 18              hist  {'colsample_bytree': 0.7, 'eta': 0.1, 'max_dep...
# 19            approx  {'colsample_bytree': 0.7, 'eta': 0.1, 'max_dep...
# 20             exact  {'colsample_bytree': 0.7, 'eta': 0.1, 'max_dep...
# 21              auto  {'colsample_bytree': 0.7, 'eta': 0.1, 'max_dep...
# 22              hist  {'colsample_bytree': 0.7, 'eta': 0.1, 'max_dep...
# 23            approx  {'colsample_bytree': 0.7, 'eta': 0.1, 'max_dep...
# 24             exact  {'colsample_bytree': 0.9, 'eta': 0.05, 'max_de...
# 25              auto  {'colsample_bytree': 0.9, 'eta': 0.05, 'max_de...
# 26              hist  {'colsample_bytree': 0.9, 'eta': 0.05, 'max_de...
# 27            approx  {'colsample_bytree': 0.9, 'eta': 0.05, 'max_de...
# 28             exact  {'colsample_bytree': 0.9, 'eta': 0.05, 'max_de...
# 29              auto  {'colsample_bytree': 0.9, 'eta': 0.05, 'max_de...
# 30              hist  {'colsample_bytree': 0.9, 'eta': 0.05, 'max_de...
# 31            approx  {'colsample_bytree': 0.9, 'eta': 0.05, 'max_de...
# 32             exact  {'colsample_bytree': 0.9, 'eta': 0.07, 'max_de...
#
# 14           0.845055           0.860663         0.853200        0.026632
# 15           0.844989           0.861345         0.851030        0.027454
# 16           0.847251           0.859459         0.853860        0.029040
# 17           0.845312           0.859716         0.852012        0.027148
# 18           0.845312           0.859716         0.852012        0.027148
# 19           0.846602           0.855648         0.849566        0.026904
# 20           0.847672           0.858089         0.853439        0.031098
# 21           0.844228           0.860334         0.851864        0.027913
# 22           0.844228           0.860334         0.851864        0.027913
# 23           0.847569           0.858178         0.851617        0.029690
# 24           0.849974           0.864038         0.858351        0.030064
# 25           0.849901           0.866788         0.860287        0.028691
# 26           0.849901           0.866788         0.860287        0.028691
# 27           0.851565           0.866910         0.860756        0.028036
# 28           0.851263           0.863476         0.859230        0.029602
# 29           0.851781           0.867684         0.861026        0.027944
# 30           0.851781           0.867684         0.861026        0.027944
# 31           0.852659           0.869079         0.860392        0.029618
# 32           0.850801           0.862422         0.857313        0.031825
# 33           0.850887           0.864212         0.859616        0.029640
# 34           0.850887           0.864212         0.859616        0.029640
# 35           0.851434           0.865097         0.859304        0.028997
# 36           0.851466           0.862084         0.858787        0.031109
# 37           0.851561           0.864783         0.860048        0.028550
# 38           0.851561           0.864783         0.860048        0.028550
# 39           0.851514           0.866011         0.858466        0.030394
# 40           0.850367           0.858392         0.853331        0.031141
# 41           0.849344           0.858756         0.856606        0.029535
# 42           0.849344           0.858756         0.856606        0.029535
# 43           0.849531           0.862774         0.856908        0.030033
# 44           0.848991           0.858623         0.855148        0.031862
# 45           0.850460           0.861527         0.857600        0.029935
# 46           0.850460           0.861527         0.857600        0.029935
# 47           0.850597           0.864020         0.856682        0.030272
#
#     rank_test_score
# 0                41
# 1                45
# 2                45
# 3                47
# 4                38
# 5                43
# 6                43
# 7                48
# 8                25
# 9                36
# 10               36
# 11               40
# 12               24
# 13               29
# 14               29
# 15               39
# 16               26
# 17               31
# 18               31
# 19               42
# 20               27
# 21               33
# 22               33
# 23               35
# 24               15
# 25                5
# 26                5
# 27                3
# 28               12
# 29                1
# 30                1
# 31                4
# 32               18
# 33                9
# 34                9
# 35               11
# 36               13
# 37                7
# 38                7
# 39               14
# 40               28
# 41               21
# 42               21
# 43               19
# 44               23
# 45               16
# 46               16
# 47               20

# %%
table.to_excel("grid_search_results_XG.xlsx",index=False)

# %%
grid_predict=grid.predict(independent)

# %%
# evaluating the model performance
from sklearn.metrics import r2_score
r_score=r2_score(Dependent,grid_predict)

# %%
print("The best value of R_score parameters:{}".format(grid.best_params_),r_score)
# Out:
# The best value of R_score parameters:{'colsample_bytree': 0.9, 'eta': 0.05, 'max_depth': 3, 'subsample': 0.9, 'tree_method': 'auto'} 0.8790478706359863

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker yes 0 or 1:"))
# Out:
# Age: 50
# BMI: 37
# children: 2
# Sex Male 0 or 1: 1
# Smoker yes 0 or 1: 1

# %%
Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Prediction={}".format(Prediction))
# Out:
# Prediction=[44315.95]
