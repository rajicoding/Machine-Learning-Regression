# %%
import pandas as pd

# %%
Dataset=pd.read_csv("insurance_pre.csv")
Dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
Dataset.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges'], dtype='object')

# %%
# Here categorical data(state) is available in the dataset which is converted to numerical data 
# As the categorical data available is nominal, one hot coding method is used to convert it into numerical data
Dataset=pd.get_dummies(Dataset,dtype=int,drop_first=True)
Dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
Dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
#Input and output split
independent=Dataset[['age', 'bmi', 'children','sex_male','smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
Dependent=Dataset[["charges"]]
Dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
#model creation
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import GridSearchCV
param_grid={'n_estimators':[50,20],
            'learning_rate':[1.0,2.0],
            'loss':['linear','square','exponential'],
            'random_state':[0,None]}
grid=GridSearchCV(AdaBoostRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,Dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\Inst_\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=AdaBoostRegressor(), n_jobs=-1,
#              param_grid={'learning_rate': [1.0, 2.0],
#                          'loss': ['linear', 'square', 'exponential'],
#                          'n_estimators': [50, 20], 'random_state': [0, None]},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.051719      0.010082         0.007256        0.000407
# 1        0.047215      0.011803         0.007592        0.000136
# 2        0.049964      0.005571         0.007070        0.001330
# 3        0.054477      0.015962         0.006917        0.000587
# 4        0.190876      0.008356         0.015765        0.000616
# 5        0.205011      0.008122         0.016389        0.000820
# 6        0.088826      0.003350         0.009534        0.001027
# 7        0.084981      0.003654         0.009521        0.000895
# 8        0.211312      0.009368         0.015966        0.000759
# 9        0.193516      0.007815         0.016191        0.000990
# 10       0.088063      0.004208         0.009263        0.001792
# 11       0.084744      0.002116         0.009593        0.000751
# 12       0.027043      0.005533         0.005317        0.000681
# 13       0.027588      0.005786         0.004919        0.000440
# 14       0.028407      0.005558         0.005320        0.000505
# 15       0.027972      0.008333         0.007104        0.001368
# 16       0.190341      0.012977         0.014867        0.000959
# 17       0.188275      0.013242         0.015414        0.000555
# 18       0.081602      0.002980         0.008899        0.001072
# 19       0.078556      0.002746         0.009089        0.000393
# 20       0.164209      0.031568         0.011147        0.003031
# 21       0.161780      0.026158         0.010777        0.002611
# 22       0.082220      0.005005         0.008032        0.000908
# 23       0.075775      0.005104         0.007439        0.001156
#
#     param_learning_rate   param_loss  param_n_estimators param_random_state  \
# 0                   1.0       linear                  50                  0
# 1                   1.0       linear                  50               None
# 2                   1.0       linear                  20                  0
# 3                   1.0       linear                  20               None
# 4                   1.0       square                  50                  0
# 5                   1.0       square                  50               None
# 6                   1.0       square                  20                  0
# 7                   1.0       square                  20               None
# 8                   1.0  exponential                  50                  0
# 9                   1.0  exponential                  50               None
# 10                  1.0  exponential                  20                  0
# 11                  1.0  exponential                  20               None
# 12                  2.0       linear                  50                  0
# 13                  2.0       linear                  50               None
# 14                  2.0       linear                  20                  0
# 15                  2.0       linear                  20               None
# 16                  2.0       square                  50                  0
# 17                  2.0       square                  50               None
# 18                  2.0       square                  20                  0
# 19                  2.0       square                  20               None
# 20                  2.0  exponential                  50                  0
# 21                  2.0  exponential                  50               None
# 22                  2.0  exponential                  20                  0
# 23                  2.0  exponential                  20               None
#
#                                                params  split0_test_score  \
# 0   {'learning_rate': 1.0, 'loss': 'linear', 'n_es...           0.852372
# 1   {'learning_rate': 1.0, 'loss': 'linear', 'n_es...           0.803526
# 2   {'learning_rate': 1.0, 'loss': 'linear', 'n_es...           0.852372
# 3   {'learning_rate': 1.0, 'loss': 'linear', 'n_es...           0.829501
# 4   {'learning_rate': 1.0, 'loss': 'square', 'n_es...           0.528579
# 5   {'learning_rate': 1.0, 'loss': 'square', 'n_es...           0.536322
# 6   {'learning_rate': 1.0, 'loss': 'square', 'n_es...           0.624317
# 7   {'learning_rate': 1.0, 'loss': 'square', 'n_es...           0.572950
# 8   {'learning_rate': 1.0, 'loss': 'exponential', ...           0.612254
# 9   {'learning_rate': 1.0, 'loss': 'exponential', ...           0.613756
# 10  {'learning_rate': 1.0, 'loss': 'exponential', ...           0.732838
# 11  {'learning_rate': 1.0, 'loss': 'exponential', ...           0.741648
# 12  {'learning_rate': 2.0, 'loss': 'linear', 'n_es...           0.873521
# 13  {'learning_rate': 2.0, 'loss': 'linear', 'n_es...           0.871499
# 14  {'learning_rate': 2.0, 'loss': 'linear', 'n_es...           0.873521
# 15  {'learning_rate': 2.0, 'loss': 'linear', 'n_es...           0.755706
# 16  {'learning_rate': 2.0, 'loss': 'square', 'n_es...           0.527178
# 17  {'learning_rate': 2.0, 'loss': 'square', 'n_es...           0.519424
# 18  {'learning_rate': 2.0, 'loss': 'square', 'n_es...           0.539102
# 19  {'learning_rate': 2.0, 'loss': 'square', 'n_es...           0.554297
# 20  {'learning_rate': 2.0, 'loss': 'exponential', ...           0.543670
# 21  {'learning_rate': 2.0, 'loss': 'exponential', ...           0.552386
# 22  {'learning_rate': 2.0, 'loss': 'exponential', ...           0.627896
# 23  {'learning_rate': 2.0, 'loss': 'exponential', ...           0.624917
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.778116           0.837977           0.782710
# 1            0.761768           0.841122           0.820554
# 2            0.778116           0.837977           0.782710
# 3            0.750007           0.827200           0.808570
# 4            0.442464           0.449198           0.488632
# 5            0.418828           0.472110           0.490111
# 6            0.538607           0.569698           0.598230
# 7            0.485797           0.635463           0.622361
# 8            0.529039           0.582869           0.608986
# 9            0.534575           0.581654           0.599525
# 10           0.683685           0.712950           0.726013
# 11           0.675206           0.719484           0.721162
# 12           0.793682           0.871146           0.831806
# 13           0.777676           0.869709           0.831758
# 14           0.793682           0.871146           0.831806
# 15           0.697690           0.871341           0.833133
# 16           0.409538           0.495753           0.522743
# 17           0.434894           0.468335           0.483287
# 18           0.445476           0.500180           0.515903
# 19           0.421072           0.493920           0.523370
# 20           0.422520           0.505573           0.535981
# 21           0.439780           0.488058           0.553453
# 22           0.542513           0.618771           0.605639
# 23           0.525837           0.586097           0.634726
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.834496         0.817134        0.030610                4
# 1            0.839082         0.813210        0.029129                6
# 2            0.834496         0.817134        0.030610                4
# 3            0.806507         0.804357        0.028741                7
# 4            0.451833         0.472141        0.032486               24
# 5            0.494331         0.482340        0.038096               22
# 6            0.551272         0.576425        0.031232               15
# 7            0.559645         0.575243        0.053096               16
# 8            0.587355         0.584101        0.029852               13
# 9            0.589307         0.583763        0.026843               14
# 10           0.742915         0.719680        0.020465                9
# 11           0.731439         0.717788        0.022729               10
# 12           0.841996         0.842430        0.029260                1
# 13           0.857887         0.841706        0.035021                3
# 14           0.841996         0.842430        0.029260                1
# 15           0.854673         0.802508        0.065688                8
# 16           0.483758         0.487794        0.042370               21
# 17           0.471540         0.475496        0.027224               23
# 18           0.468689         0.493870        0.033308               20
# 19           0.489126         0.496357        0.044301               19
# 20           0.522230         0.505995        0.043705               18
# 21           0.520762         0.510888        0.042916               17
# 22           0.598976         0.598759        0.029868               11
# 23           0.608211         0.595958        0.038745               12

# %%
table.to_excel("grid_search_results.AB.xlsx",index=False)

# %%
grid_predict=grid.predict(independent)

# %%
# evaluating the model performance
from sklearn.metrics import r2_score
r_score=r2_score(Dependent,grid_predict)

# %%
print("The R_score value of the best parameter {}".format(grid.best_params_),r_score)
# Out:
# The R_score value of the best parameter {'learning_rate': 2.0, 'loss': 'linear', 'n_estimators': 50, 'random_state': 0} 0.8552200456449022

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker yes 0 or 1:"))
# Out:
# Age: 48
# BMI: 37
# children: 3
# Sex Male 0 or 1: 0
# Smoker yes 0 or 1: 1

# %%
Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Prediction={}".format(Prediction))
# Out:
# Prediction=[46577.1355051]
# C:\Users\Inst_\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
#   warnings.warn(
