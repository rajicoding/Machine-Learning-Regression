# %%
import pickle

# %%
# Preprocessing steps are loaded and assigned to sc
sc=pickle.load(open('StandardScaler.pkl','rb'))

# %%
preinput=sc.transform([[1400,12000,4500,1,0]])
# Out:
# C:\Users\Inst_\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
preinput
# Out:
# array([[-1.46550442, -4.33835385, -1.50361142,  2.        , -0.76870611]])

# %%
# loading the model to verify the result
loaded_model=pickle.load(open("finalized_model_svr_inp.sav",'rb'))
result=loaded_model.predict(preinput)

# %%
result
# Out:
# array([59945.0017105])
