# %%
import pandas as pd

# %%
Dataset=pd.read_csv("insurance_pre.csv")
Dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
Dataset.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges'], dtype='object')

# %%
# Here categorical data(state) is available in the dataset which is converted to numerical data 
# As the categorical data available is nominal, one hot coding method is used to convert it into numerical data
Dataset=pd.get_dummies(Dataset,dtype=int,drop_first=True)
Dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %% [markdown]
# Input and output split

# %%
independent=Dataset[['age', 'bmi', 'children','sex_male','smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
Dependent=Dataset[["charges"]]
Dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %% [markdown]
# Input and output split

# %%
# model creation using Gridsearchcv
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid={'kernel':['linear','rbf','poly','sigmoid'],
            'C':[500,1000,2000,3000,4000,6000,10000],
            'max_iter':[1000,2000,4000,6000,8000,12000,20000],
            'epsilon':[0.1,0.5,1.0],
           'gamma':['auto','scale']}
grid= GridSearchCV(SVR(),param_grid,refit=True,verbose=3,n_jobs=-1)

# fitting the model for grid search
grid.fit(independent,Dependent)
# Out:
# Fitting 5 folds for each of 1176 candidates, totalling 5880 fits
# C:\Users\Inst_\anaconda3\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# C:\Users\Inst_\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Inst_\anaconda3\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=20000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [500, 1000, 2000, 3000, 4000, 6000, 10000],
#                          'epsilon': [0.1, 0.5, 1.0], 'gamma': ['auto', 'scale'],
#                          'kernel': ['linear', 'rbf', 'poly', 'sigmoid'],
#                          'max_iter': [1000, 2000, 4000, 6000, 8000, 12000,
#                                       20000]},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0          0.109404      0.011335         0.014730        0.000397      500
# 1          0.143782      0.010888         0.015625        0.000582      500
# 2          0.206424      0.007439         0.017513        0.001248      500
# 3          0.273868      0.009239         0.017911        0.002012      500
# 4          0.329888      0.007825         0.017336        0.000439      500
# ...             ...           ...              ...             ...      ...
# 1171       0.192315      0.003441         0.044680        0.000450    10000
# 1172       0.203425      0.002246         0.043207        0.000704    10000
# 1173       0.200442      0.002697         0.039405        0.001088    10000
# 1174       0.190803      0.007424         0.039153        0.002340    10000
# 1175       0.172793      0.002332         0.027777        0.004804    10000
#
#       param_epsilon param_gamma param_kernel  param_max_iter  \
# 0               0.1        auto       linear            1000
# 1               0.1        auto       linear            2000
# 2               0.1        auto       linear            4000
# 3               0.1        auto       linear            6000
# 4               0.1        auto       linear            8000
# ...             ...         ...          ...             ...
# 1171            1.0       scale      sigmoid            4000
# 1172            1.0       scale      sigmoid            6000
# 1173            1.0       scale      sigmoid            8000
# 1174            1.0       scale      sigmoid           12000
# 1175            1.0       scale      sigmoid           20000
#
#                                                  params  split0_test_score  \
# 0     {'C': 500, 'epsilon': 0.1, 'gamma': 'auto', 'k...           0.617007
# 1     {'C': 500, 'epsilon': 0.1, 'gamma': 'auto', 'k...           0.619325
# 2     {'C': 500, 'epsilon': 0.1, 'gamma': 'auto', 'k...           0.620058
# 3     {'C': 500, 'epsilon': 0.1, 'gamma': 'auto', 'k...           0.613534
# 4     {'C': 500, 'epsilon': 0.1, 'gamma': 'auto', 'k...           0.626239
# ...                                                 ...                ...
# 1171  {'C': 10000, 'epsilon': 1.0, 'gamma': 'scale',...        -157.507980
# 1172  {'C': 10000, 'epsilon': 1.0, 'gamma': 'scale',...        -157.507980
# 1173  {'C': 10000, 'epsilon': 1.0, 'gamma': 'scale',...        -157.507980
# 1174  {'C': 10000, 'epsilon': 1.0, 'gamma': 'scale',...        -157.507980
# 1175  {'C': 10000, 'epsilon': 1.0, 'gamma': 'scale',...        -157.507980
#
#       split1_test_score  split2_test_score  split3_test_score  \
# 0              0.567280           0.582686           0.579490
# 1              0.569801           0.582946           0.592386
# 2              0.556299           0.596699           0.590935
# 3              0.581009           0.607397           0.602005
# 4              0.574731           0.539804           0.605402
# ...                 ...                ...                ...
# 1171        -212.288660        -178.166630        -172.476929
# 1172        -212.288660        -178.166630        -172.476929
# 1173        -212.288660        -178.166630        -172.476929
# 1174        -212.288660        -178.166630        -172.476929
# 1175        -212.288660        -178.166630        -172.476929
#
#       split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0              0.592502         0.587793        0.016682              217
# 1              0.541728         0.581237        0.025572              227
# 2              0.591835         0.591165        0.020404              211
# 3              0.556196         0.592028        0.020993              207
# 4              0.579663         0.585168        0.029303              221
# ...                 ...              ...             ...              ...
# 1171        -154.800555      -175.048151       20.595215             1100
# 1172        -154.800555      -175.048151       20.595215             1100
# 1173        -154.800555      -175.048151       20.595215             1100
# 1174        -154.800555      -175.048151       20.595215             1100
# 1175        -154.800555      -175.048151       20.595215             1100
#
# [1176 rows x 18 columns]

# %%
grid_predict=grid.predict(independent)

# %%
# evaluating the model performance
from sklearn.metrics import r2_score
r_score=r2_score(Dependent,grid_predict)

# %%
print("The R_score value for best parameter{}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter{'C': 1000, 'epsilon': 0.5, 'gamma': 'auto', 'kernel': 'linear', 'max_iter': 20000}: 0.7090704635600454

# %%
table.to_excel("grid_search_results_svr.xlsx",index=False)

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker yes 0 or 1:"))
# Out:
# Age: 37
# BMI: 50
# children: 3
# Sex Male 0 or 1: 0
# Smoker yes 0 or 1: 1

# %%
Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Prediction={}".format(Prediction))
# Out:
# Prediction=[32720.33054727]
# C:\Users\Inst_\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
