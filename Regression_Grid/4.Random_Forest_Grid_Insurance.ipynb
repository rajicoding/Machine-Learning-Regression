# %%
import pandas as pd

# %%
Dataset=pd.read_csv("insurance_pre.csv")
Dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
Dataset.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges'], dtype='object')

# %%
# Here categorical data(state) is available in the dataset which is converted to numerical data 
# As the categorical data available is nominal, one hot coding method is used to convert it into numerical data
Dataset=pd.get_dummies(Dataset,dtype=int,drop_first=True)
Dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
Dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
#Input and output split
independent=Dataset[['age', 'bmi', 'children','sex_male','smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
Dependent=Dataset[["charges"]]
Dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
#model creation
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
param_grid={'criterion':['squared_error','friedman_mse','absolute_error','poisson'],
            'max_features':[None,'sqrt','log2'],
            'max_depth':[4,5],
            'n_estimators':[100,50],
            'random_state':[0,None]}
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,Dependent)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# C:\Users\Inst_\anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_depth': [4, 5],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [100, 50], 'random_state': [0, None]},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.323768      0.006632         0.013488        0.001242
# 1        0.340878      0.019296         0.016377        0.002289
# 2        0.173384      0.010017         0.009898        0.001070
# 3        0.185697      0.014519         0.009196        0.000626
# 4        0.290008      0.030227         0.015015        0.001051
# ..            ...           ...              ...             ...
# 91       0.213485      0.006788         0.009371        0.000904
# 92       0.393652      0.008070         0.013147        0.000625
# 93       0.398258      0.009900         0.012102        0.000844
# 94       0.200470      0.006310         0.008540        0.001418
# 95       0.182879      0.014110         0.006342        0.001996
#
#    param_criterion  param_max_depth param_max_features  param_n_estimators  \
# 0    squared_error                4               None                 100
# 1    squared_error                4               None                 100
# 2    squared_error                4               None                  50
# 3    squared_error                4               None                  50
# 4    squared_error                4               sqrt                 100
# ..             ...              ...                ...                 ...
# 91         poisson                5               sqrt                  50
# 92         poisson                5               log2                 100
# 93         poisson                5               log2                 100
# 94         poisson                5               log2                  50
# 95         poisson                5               log2                  50
#
#    param_random_state                                             params  \
# 0                   0  {'criterion': 'squared_error', 'max_depth': 4,...
# 1                None  {'criterion': 'squared_error', 'max_depth': 4,...
# 2                   0  {'criterion': 'squared_error', 'max_depth': 4,...
# 3                None  {'criterion': 'squared_error', 'max_depth': 4,...
# 4                   0  {'criterion': 'squared_error', 'max_depth': 4,...
# ..                ...                                                ...
# 91               None  {'criterion': 'poisson', 'max_depth': 5, 'max_...
# 92                  0  {'criterion': 'poisson', 'max_depth': 5, 'max_...
# 93               None  {'criterion': 'poisson', 'max_depth': 5, 'max_...
# 94                  0  {'criterion': 'poisson', 'max_depth': 5, 'max_...
# 95               None  {'criterion': 'poisson', 'max_depth': 5, 'max_...
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0            0.883547           0.802104           0.888839
# 1            0.883050           0.799811           0.889369
# 2            0.884065           0.801412           0.889322
# 3            0.883373           0.800278           0.887419
# 4            0.849320           0.790547           0.839960
# ..                ...                ...                ...
# 91           0.868555           0.803355           0.871137
# 92           0.863183           0.807126           0.866334
# 93           0.862380           0.803142           0.863753
# 94           0.858375           0.805988           0.863844
# 95           0.865905           0.798813           0.865990
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0            0.843726           0.873092         0.858262        0.032122
# 1            0.841503           0.873034         0.857353        0.033147
# 2            0.843254           0.871920         0.857994        0.032477
# 3            0.842418           0.871470         0.856992        0.032435
# 4            0.820610           0.838212         0.827730        0.020779
# ..                ...                ...              ...             ...
# 91           0.838255           0.848782         0.846017        0.024605
# 92           0.838530           0.855451         0.846125        0.021748
# 93           0.832856           0.843463         0.841119        0.022273
# 94           0.842489           0.855495         0.845238        0.020843
# 95           0.838212           0.847701         0.843324        0.024699
#
#     rank_test_score
# 0                 1
# 1                11
# 2                 4
# 3                12
# 4                66
# ..              ...
# 91               36
# 92               34
# 93               56
# 94               37
# 95               47
#
# [96 rows x 18 columns]

# %%
table.to_excel("grid_search_results_RF.xlsx",index=False)

# %%
grid_predict=grid.predict(independent)

# %%
# evaluating the model performance
from sklearn.metrics import r2_score
r_score=r2_score(Dependent,grid_predict)

# %%
print("The R_score value for Best parameter{}".format(grid.best_params_),r_score)
# Out:
# The R_score value for Best parameter{'criterion': 'squared_error', 'max_depth': 4, 'max_features': None, 'n_estimators': 100, 'random_state': 0} 0.8749064012416777

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker yes 0 or 1:"))
# Out:
# Age: 39
# BMI: 35
# children: 1
# Sex Male 0 or 1: 1
# Smoker yes 0 or 1: 0

# %%
Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Prediction={}".format(Prediction))
# Out:
# Prediction=[6998.76977277]
# C:\Users\Inst_\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
