# %%
import pandas as pd

# %%
Dataset=pd.read_csv("insurance_pre.csv")
Dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
Dataset.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges'], dtype='object')

# %%
# Here categorical data(state) is available in the dataset which is converted to numerical data 
# As the categorical data available is nominal, one hot coding method is used to convert it into numerical data
Dataset=pd.get_dummies(Dataset,dtype=int,drop_first=True)
Dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
Dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
#Input and output split
independent=Dataset[['age', 'bmi', 'children','sex_male','smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
Dependent=Dataset[["charges"]]
Dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
#model creation using GridSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid={'criterion':['squared_error','friedman_mse','absolute_error','poisson'],
            'max_features':[None,'sqrt','log2'],
            'max_depth':[4,6],
            'splitter':['best','random'],
            'random_state':[0,None]}
grid= GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)

# fitting the model for grid search
grid.fit(independent,Dependent)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_depth': [4, 6],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'random_state': [0, None],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.005984      0.000842         0.005070        0.000657
# 1        0.007758      0.001474         0.003335        0.000359
# 2        0.005010      0.000725         0.003549        0.000548
# 3        0.005558      0.000531         0.004105        0.001059
# 4        0.005324      0.000655         0.003488        0.000241
# ..            ...           ...              ...             ...
# 91       0.007959      0.001223         0.004077        0.000667
# 92       0.008130      0.000934         0.004333        0.000595
# 93       0.007462      0.001072         0.004784        0.000276
# 94       0.008832      0.000867         0.003438        0.000369
# 95       0.005767      0.000582         0.002927        0.000196
#
#    param_criterion  param_max_depth param_max_features param_random_state  \
# 0    squared_error                4               None                  0
# 1    squared_error                4               None                  0
# 2    squared_error                4               None               None
# 3    squared_error                4               None               None
# 4    squared_error                4               sqrt                  0
# ..             ...              ...                ...                ...
# 91         poisson                6               sqrt               None
# 92         poisson                6               log2                  0
# 93         poisson                6               log2                  0
# 94         poisson                6               log2               None
# 95         poisson                6               log2               None
#
#    param_splitter                                             params  \
# 0            best  {'criterion': 'squared_error', 'max_depth': 4,...
# 1          random  {'criterion': 'squared_error', 'max_depth': 4,...
# 2            best  {'criterion': 'squared_error', 'max_depth': 4,...
# 3          random  {'criterion': 'squared_error', 'max_depth': 4,...
# 4            best  {'criterion': 'squared_error', 'max_depth': 4,...
# ..            ...                                                ...
# 91         random  {'criterion': 'poisson', 'max_depth': 6, 'max_...
# 92           best  {'criterion': 'poisson', 'max_depth': 6, 'max_...
# 93         random  {'criterion': 'poisson', 'max_depth': 6, 'max_...
# 94           best  {'criterion': 'poisson', 'max_depth': 6, 'max_...
# 95         random  {'criterion': 'poisson', 'max_depth': 6, 'max_...
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0            0.872782           0.785014           0.884006
# 1            0.731552           0.702314           0.789553
# 2            0.872782           0.785014           0.884006
# 3            0.776091           0.754581           0.869149
# 4            0.816686           0.732077           0.831470
# ..                ...                ...                ...
# 91           0.823434           0.675153           0.782174
# 92           0.843109           0.737472           0.853910
# 93           0.736891           0.744949           0.794739
# 94           0.855883           0.742862           0.856152
# 95           0.775276           0.688586           0.796057
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0            0.836656           0.866989         0.849089        0.035668
# 1            0.740197           0.734363         0.739596        0.028207
# 2            0.836656           0.866989         0.849089        0.035668
# 3            0.785641           0.739333         0.784959        0.045103
# 4            0.806736           0.824472         0.802288        0.036056
# ..                ...                ...              ...             ...
# 91           0.669122           0.798563         0.749689        0.064698
# 92           0.811552           0.855426         0.820294        0.044319
# 93           0.696877           0.738347         0.742361        0.031193
# 94           0.628324           0.842595         0.785163        0.089137
# 95           0.738519           0.725773         0.744842        0.037729
#
#     rank_test_score
# 0                 3
# 1                60
# 2                 3
# 3                44
# 4                28
# ..              ...
# 91               51
# 92               18
# 93               54
# 94               43
# 95               53
#
# [96 rows x 18 columns]

# %%
grid_predict=grid.predict(independent)

# %%
# evaluating the model performance
from sklearn.metrics import r2_score
r_score=r2_score(Dependent,grid_predict)

# %%
print("The R_score value for best parameter{}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter{'criterion': 'poisson', 'max_depth': 4, 'max_features': None, 'random_state': 0, 'splitter': 'best'}: 0.8681716418321382

# %%
table.to_excel("grid_search_results_DT.xlsx",index=False)

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker yes 0 or 1:"))
# Out:
# Age: 45
# BMI: 37
# children: 2
# Sex Male 0 or 1: 0
# Smoker yes 0 or 1: 0

# %%
Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Prediction={}".format(Prediction))
# Out:
# Prediction=[9378.79071988]
# C:\Users\Inst_\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
